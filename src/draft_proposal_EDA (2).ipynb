# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Dataset can be downloaded from this link : https://docs.google.com/spreadsheets/d/1Bi_slUGz4cPL5Ng1QOYFTRh4t8d_w0ZulvKm9JVX5tU/edit?usp=sharing
# Note that this dataset can only be accessed using the UMBC mail id.

df = pd.read_csv("Dataset_scraped.csv")
print("There are {} observations for {} predictors.".format(df.shape[0],df.shape[1]))
df.head()
# Out:
# There are 300257 observations for 25 predictors.
#    Unnamed: 0   airline   from      to  price class_category  class  day  \
# 0           0  SpiceJet  Delhi  Mumbai   5953        Economy      0   11
# 1           1  SpiceJet  Delhi  Mumbai   5953        Economy      0   11
# 2           2   AirAsia  Delhi  Mumbai   5956        Economy      0   11
# 3           3   Vistara  Delhi  Mumbai   5955        Economy      0   11
# 4           4   Vistara  Delhi  Mumbai   5955        Economy      0   11
#
#    month flight_no  ... airline_index  route_index  duration_in_min stops  \
# 0      2   SG-8709  ...             4           14              130     0
# 1      2   SG-8157  ...             4           14              140     0
# 2      2    I5-764  ...             1           14              130     0
# 3      2    UK-995  ...             7           14              135     0
# 4      2    UK-963  ...             7           14              140     0
#
# ...

# %%
df=df.drop('Unnamed: 0', axis=1)

# %%
df.head()
# Out:
#     airline   from      to  price class_category  class  day  month flight_no  \
# 0  SpiceJet  Delhi  Mumbai   5953        Economy      0   11      2   SG-8709
# 1  SpiceJet  Delhi  Mumbai   5953        Economy      0   11      2   SG-8157
# 2   AirAsia  Delhi  Mumbai   5956        Economy      0   11      2    I5-764
# 3   Vistara  Delhi  Mumbai   5955        Economy      0   11      2    UK-995
# 4   Vistara  Delhi  Mumbai   5955        Economy      0   11      2    UK-963
#
#           route  ...  airline_index  route_index duration_in_min stops  \
# 0  Delhi-Mumbai  ...              4           14             130     0
# 1  Delhi-Mumbai  ...              4           14             140     0
# 2  Delhi-Mumbai  ...              1           14             130     0
# 3  Delhi-Mumbai  ...              7           14             135     0
# 4  Delhi-Mumbai  ...              7           14             140     0
#
#    stops_category  arr_daytime  arr_daytime_category  dep_daytime  \
# ...

# %%
df.tail()
# Out:
#         airline     from         to  price class_category  class  day  month  \
# 300252  Vistara  Chennai  Hyderabad  69265       Business      1   31      3
# 300253  Vistara  Chennai  Hyderabad  77105       Business      1   31      3
# 300254  Vistara  Chennai  Hyderabad  79099       Business      1   31      3
# 300255  Vistara  Chennai  Hyderabad  81585       Business      1   31      3
# 300256  Vistara  Chennai  Hyderabad  81585       Business      1   31      3
#
#        flight_no              route  ...  airline_index  route_index  \
# 300252    UK-822  Chennai-Hyderabad  ...              7            7
# 300253    UK-826  Chennai-Hyderabad  ...              7            7
# 300254    UK-832  Chennai-Hyderabad  ...              7            7
# 300255    UK-828  Chennai-Hyderabad  ...              7            7
# 300256    UK-822  Chennai-Hyderabad  ...              7            7
#
#        duration_in_min stops  stops_category  arr_daytime  \
# ...

# %%
df.shape
# Out:
# (300257, 24)

# %%
df.isnull().sum()
# Out:
# airline                 0
# from                    0
# to                      0
# price                   0
# class_category          0
# class                   0
# day                     0
# month                   0
# flight_no               0
# route                   0
# dep_hour                0
# arr_hour                0
# dep_period              0
# arr_period              0
# airline_index           0
# route_index             0
# duration_in_min         0
# stops                   0
# stops_category          0
# arr_daytime             0
# arr_daytime_category    0
# dep_daytime             0
# dep_daytime_category    0
# month_category          0
# dtype: int64

# %%
df.describe(include='all')
# Out:
#         airline    from      to          price class_category          class  \
# count    300257  300257  300257  300257.000000         300257  300257.000000
# unique        8       6       6            NaN              2            NaN
# top     Vistara   Delhi  Mumbai            NaN        Economy            NaN
# freq     127859   61345   59108            NaN         206770            NaN
# mean        NaN     NaN     NaN   20883.926526            NaN       0.311357
# std         NaN     NaN     NaN   22695.990185            NaN       0.463049
# min         NaN     NaN     NaN    1105.000000            NaN       0.000000
# 25%         NaN     NaN     NaN    4783.000000            NaN       0.000000
# 50%         NaN     NaN     NaN    7425.000000            NaN       0.000000
# 75%         NaN     NaN     NaN   42521.000000            NaN       1.000000
# max         NaN     NaN     NaN  123071.000000            NaN       1.000000
#
# ...

# %%
df.describe()
# Out:
#                price          class            day          month  \
# count  300257.000000  300257.000000  300257.000000  300257.000000
# mean    20883.926526       0.311357      17.384507       2.665004
# std     22695.990185       0.463049       8.074000       0.471990
# min      1105.000000       0.000000       1.000000       2.000000
# 25%      4783.000000       0.000000      12.000000       2.000000
# 50%      7425.000000       0.000000      18.000000       3.000000
# 75%     42521.000000       1.000000      24.000000       3.000000
# max    123071.000000       1.000000      31.000000       3.000000
#
#             dep_hour       arr_hour  airline_index    route_index  \
# count  300257.000000  300257.000000  300257.000000  300257.000000
# mean       12.983587      15.238982       3.741501      14.974002
# std         5.363147       6.050226       3.001990       8.835377
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
df.nunique()
# Out:
# airline                     8
# from                        6
# to                          6
# price                   12165
# class_category              2
# class                       2
# day                        31
# month                       2
# flight_no                1569
# route                      30
# dep_hour                   24
# arr_hour                   24
# dep_period                  4
# arr_period                  4
# airline_index               8
# route_index                30
# duration_in_min           476
# stops                       3
# stops_category              3
# arr_daytime                 2
# arr_daytime_category        2
# dep_daytime                 2
# dep_daytime_category        2
# month_category              2
# dtype: int64
